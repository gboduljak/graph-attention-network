# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: anyio==3.6.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (3.6.2)
# Requirement already satisfied: appnope==0.1.3 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (0.1.3)
# Requirement already satisfied: argon2-cffi==21.3.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: arrow==1.2.3 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.2.3)
# Requirement already satisfied: asttokens==2.2.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: attrs==22.1.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (22.1.0)
# Requirement already satisfied: backcall==0.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: backports.zoneinfo==0.2.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (0.2.1)
# Requirement already satisfied: beautifulsoup4==4.11.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (4.11.1)
# Requirement already satisfied: bleach==5.0.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (5.0.1)
# Requirement already satisfied: cachetools==5.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (5.2.0)
# Requirement already satisfied: certifi==2022.12.7 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (2022.12.7)
# Requirement already satisfied: cffi==1.15.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (1.15.1)
# Requirement already satisfied: chardet==3.0.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (3.0.4)
# Requirement already satisfied: charset-normalizer==2.1.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (2.1.1)
# Requirement already satisfied: comm==0.1.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (0.1.2)
# Requirement already satisfied: contourpy==1.0.6 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (1.0.6)
# Requirement already satisfied: cycler==0.11.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (0.11.0)
# Requirement already satisfied: debugpy==1.6.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (1.6.4)
# Requirement already satisfied: decorator==5.1.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 22)) (0.7.1)
# Requirement already satisfied: docopt==0.6.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (0.6.2)
# Requirement already satisfied: entrypoints==0.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 24)) (0.4)
# Requirement already satisfied: executing==1.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.16.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (2.16.2)
# Requirement already satisfied: fonttools==4.38.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (4.38.0)
# Requirement already satisfied: fqdn==1.5.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 28)) (1.5.1)
# Requirement already satisfied: google-auth==1.4.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (1.4.2)
# Requirement already satisfied: idna==3.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (3.4)
# Requirement already satisfied: importlib-metadata==5.1.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 31)) (5.1.0)
# Requirement already satisfied: importlib-resources==5.10.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (5.10.1)
# Requirement already satisfied: ipykernel==6.19.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 33)) (6.19.2)
# Requirement already satisfied: ipython==8.7.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (8.7.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.0.3 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (8.0.3)
# Requirement already satisfied: isoduration==20.11.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (20.11.0)
# Requirement already satisfied: isort==5.11.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (5.11.2)
# Requirement already satisfied: jedi==0.18.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 40)) (3.1.2)
# Requirement already satisfied: joblib==1.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (1.2.0)
# Requirement already satisfied: Js2Py==0.74 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (0.74)
# Requirement already satisfied: jsonpointer==2.3 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (2.3)
# Requirement already satisfied: jsonschema==4.17.3 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (4.17.3)
# Requirement already satisfied: jupyter==1.0.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (1.0.0)
# Requirement already satisfied: jupyter-console==6.4.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (6.4.4)
# Requirement already satisfied: jupyter-events==0.5.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (0.5.0)
# Requirement already satisfied: jupyter_client==7.4.8 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (7.4.8)
# Requirement already satisfied: jupyter_core==5.1.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 49)) (5.1.0)
# Requirement already satisfied: jupyter_server==2.0.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (2.0.1)
# Requirement already satisfied: jupyter_server_terminals==0.4.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (0.4.2)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==3.0.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 53)) (3.0.4)
# Requirement already satisfied: kiwisolver==1.4.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (1.4.4)
# Requirement already satisfied: MarkupSafe==2.1.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (2.1.1)
# Requirement already satisfied: matplotlib==3.6.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (3.6.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 57)) (0.1.6)
# Requirement already satisfied: mistune==2.0.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (2.0.4)
# Requirement already satisfied: nbclassic==0.4.8 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (0.4.8)
# Requirement already satisfied: nbclient==0.7.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 60)) (0.7.2)
# Requirement already satisfied: nbconvert==7.2.6 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (7.2.6)
# Requirement already satisfied: nbformat==5.7.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (5.7.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (1.5.6)
# Requirement already satisfied: networkx==2.8.8 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 64)) (2.8.8)
# Requirement already satisfied: notebook==6.5.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 65)) (6.5.2)
# Requirement already satisfied: notebook_shim==0.2.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 66)) (0.2.2)
# Requirement already satisfied: numpy==1.23.5 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 67)) (1.23.5)
# Requirement already satisfied: packaging==22.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 68)) (22.0)
# Requirement already satisfied: pandas==1.5.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 69)) (1.5.2)
# Requirement already satisfied: pandocfilters==1.5.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 70)) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 71)) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 72)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 73)) (0.7.5)
# Requirement already satisfied: Pillow==9.3.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 74)) (9.3.0)
# Requirement already satisfied: pkgutil_resolve_name==1.3.10 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 75)) (1.3.10)
# Requirement already satisfied: platformdirs==2.6.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 76)) (2.6.0)
# Requirement already satisfied: portpicker==1.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 77)) (1.2.0)
# Requirement already satisfied: prometheus-client==0.15.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 78)) (0.15.0)
# Requirement already satisfied: prompt-toolkit==3.0.36 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 79)) (3.0.36)
# Requirement already satisfied: psutil==5.9.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 80)) (5.9.4)
# Requirement already satisfied: ptyprocess==0.7.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 81)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 82)) (0.2.2)
# Requirement already satisfied: pyasn1==0.4.8 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 83)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 84)) (0.2.8)
# Requirement already satisfied: pycodestyle==2.10.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 85)) (2.10.0)
# Requirement already satisfied: pycparser==2.21 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 86)) (2.21)
# Requirement already satisfied: pyg-lib==0.1.0+pt113 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 87)) (0.1.0+pt113)
# Requirement already satisfied: Pygments==2.13.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 88)) (2.13.0)
# Requirement already satisfied: pyjsparser==2.7.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 89)) (2.7.1)
# Requirement already satisfied: pyparsing==3.0.9 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 90)) (3.0.9)
# Requirement already satisfied: PyPrind==2.11.3 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 91)) (2.11.3)
# Requirement already satisfied: pyrsistent==0.19.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 92)) (0.19.2)
# Requirement already satisfied: pySmartDL==1.3.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 93)) (1.3.4)
# Requirement already satisfied: python-dateutil==2.8.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 94)) (2.8.2)
# Requirement already satisfied: python-json-logger==2.0.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 95)) (2.0.4)
# Requirement already satisfied: pytz==2022.6 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 96)) (2022.6)
# Requirement already satisfied: pytz-deprecation-shim==0.1.0.post0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 97)) (0.1.0.post0)
# Requirement already satisfied: PyYAML==6.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 98)) (6.0)
# Requirement already satisfied: pyzmq==24.0.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 99)) (24.0.1)
# Requirement already satisfied: qtconsole==5.4.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 100)) (5.4.0)
# Requirement already satisfied: QtPy==2.3.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 101)) (2.3.0)
# Requirement already satisfied: requests==2.28.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 102)) (2.28.1)
# Requirement already satisfied: rfc3339-validator==0.1.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 103)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 104)) (0.1.1)
# Requirement already satisfied: rsa==4.9 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 105)) (4.9)
# Requirement already satisfied: scikit-learn==1.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 106)) (1.2.0)
# Requirement already satisfied: scipy==1.9.3 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 107)) (1.9.3)
# Requirement already satisfied: seaborn==0.12.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 108)) (0.12.1)
# Requirement already satisfied: Send2Trash==1.8.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 109)) (1.8.0)
# Requirement already satisfied: simplegeneric==0.8.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 110)) (0.8.1)
# Requirement already satisfied: six==1.16.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 111)) (1.16.0)
# Requirement already satisfied: sklearn==0.0.post1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 112)) (0.0.post1)
# Requirement already satisfied: sniffio==1.3.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 113)) (1.3.0)
# Requirement already satisfied: soupsieve==2.3.2.post1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 114)) (2.3.2.post1)
# Requirement already satisfied: stack-data==0.6.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 115)) (0.6.2)
# Requirement already satisfied: terminado==0.13.3 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 116)) (0.13.3)
# Requirement already satisfied: threadpoolctl==3.1.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 117)) (3.1.0)
# Requirement already satisfied: tinycss2==1.2.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 118)) (1.2.1)
# Requirement already satisfied: tomli==2.0.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 119)) (2.0.1)
# Requirement already satisfied: torch==1.13.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 120)) (1.13.0)
# Requirement already satisfied: torch-cluster==1.6.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 121)) (1.6.0)
# Requirement already satisfied: torch-geometric==2.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 122)) (2.2.0)
# Requirement already satisfied: torch-scatter==2.1.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 123)) (2.1.0)
# Requirement already satisfied: torch-sparse==0.6.15 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 124)) (0.6.15)
# Requirement already satisfied: torch-spline-conv==1.2.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 125)) (1.2.1)
# Requirement already satisfied: torchmetrics==0.11.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 126)) (0.11.0)
# Requirement already satisfied: tornado==6.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (6.2)
# Requirement already satisfied: tqdm==4.64.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 128)) (4.64.1)
# Requirement already satisfied: traitlets==5.7.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 129)) (5.7.1)
# Requirement already satisfied: typing_extensions==4.4.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 130)) (4.4.0)
# Requirement already satisfied: tzdata==2022.7 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 131)) (2022.7)
# Requirement already satisfied: tzlocal==4.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 132)) (4.2)
# Requirement already satisfied: uri-template==1.2.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 133)) (1.2.0)
# Requirement already satisfied: urllib3==1.26.13 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 134)) (1.26.13)
# Requirement already satisfied: wcwidth==0.2.5 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 135)) (0.2.5)
# Requirement already satisfied: webcolors==1.12 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 136)) (1.12)
# Requirement already satisfied: webencodings==0.5.1 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 137)) (0.5.1)
# Requirement already satisfied: websocket-client==1.4.2 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 138)) (1.4.2)
# Requirement already satisfied: widgetsnbextension==4.0.4 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 139)) (4.0.4)
# Requirement already satisfied: yapf==0.32.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 140)) (0.32.0)
# Requirement already satisfied: zipp==3.11.0 in ./grl-env/lib/python3.8/site-packages (from -r requirements.txt (line 141)) (3.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from torch_geometric.datasets import PPI
from torch_geometric.loader import DataLoader
from torch_geometric.transforms import AddSelfLoops
import dataset

train_dataset = PPI(root='', split='train', transform=AddSelfLoops())
val_dataset = PPI(root='', split='val', transform=AddSelfLoops())
test_dataset = PPI(root='', split='test', transform=AddSelfLoops())

dataset.num_features = 50
dataset.num_labels = 121
dataset.train_loader = DataLoader(train_dataset, batch_size=2)
dataset.val_loader = DataLoader(val_dataset, batch_size=2)
dataset.test_loader = DataLoader(test_dataset, batch_size=2)

# %%
import torch
from models import GATv1PPI
from evaluation import evaluate
from device import device

seed = 42
model = GATv1PPI(dataset.num_features, dataset.num_labels)
model_state_dict = torch.load(f'weights/seed-{seed}/GATv1PPI', map_location=device)['model_state_dict']
model.load_state_dict(model_state_dict)

evaluate(model, dataset.test_loader)
# Out:
# (tensor(0.0582), tensor(0.9765))

# %%
from torch_geometric.utils import to_networkx

[test_graph] = list(dataset.test_loader)
test_graph_nx = to_networkx(test_graph)

print(test_graph)
print(test_graph_nx)
# Out:
# DataBatch(x=[5524, 50], edge_index=[2, 167500], y=[5524, 121], batch=[5524], ptr=[3])
# DiGraph with 5524 nodes and 167500 edges

# %% [markdown]
# ### Attention Distribution Analysis

# %%
from attention_entropy_visualisation import visualise_attention_entropy, AttentionVisualisationMode

# %%
visualise_attention_entropy(model, test_graph, [4,4,6], AttentionVisualisationMode.PER_LAYER)

# %%
visualise_attention_entropy(model, test_graph, [1,1,1], AttentionVisualisationMode.PER_HEAD)

# %% [markdown]
# ### Neighbourhood Attention Analysis

# %%
from node_degree_analysis import print_nodes_with_degs
from neighbourhood_analysis_visualisation import visualise_neighbourhoods_for, NeighbourhoodVisualisationMode

# %%
print_nodes_with_degs(test_graph_nx)
# Out:
# (853, 355)
# (3946, 305)
# (2210, 285)
# (489, 270)
# (1130, 245)
# (4454, 235)
# (857, 230)
# (2184, 225)
# (4750, 220)
# (1829, 210)
# (2308, 200)
# (1994, 195)
# (1026, 185)
# (1269, 180)
# (2233, 175)
# (1993, 170)
# (1030, 165)
# (1990, 160)
# (237, 155)
# (3839, 150)
# (209, 145)
# (4847, 140)
# (2798, 135)
# (213, 130)
# (377, 125)
# (2715, 120)
# (367, 115)
# (1012, 110)
# (2739, 105)
# (342, 100)
# (850, 95)
# (2108, 90)
# (217, 85)
# (12, 80)
# (423, 75)
# (236, 70)
# (1303, 65)
# (458, 60)
# (1456, 55)
# (214, 50)
# (14, 45)
# (47, 40)
# (86, 35)
# (258, 30)
# (2, 25)
# (0, 20)
# (30, 15)
# (106, 10)
# (29, 5)

# %%
nodes_to_visualise = [29, 106, 30, 0]

# %% [markdown]
# #### Report plots

# %%
visualise_neighbourhoods_for(model, test_graph, 0, 0, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_HEAD)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.2869, min attention: 0.1214
# neighbourhood stats for node=106:
# 	max attention: 0.7445, min attention: 0.0015
# neighbourhood stats for node=30:
# 	max attention: 0.6546, min attention: 0.0062
# neighbourhood stats for node=0:
# 	max attention: 0.6502, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 1, 0, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_HEAD)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.4588, min attention: 0.0099
# neighbourhood stats for node=106:
# 	max attention: 0.9114, min attention: 0.0000
# neighbourhood stats for node=30:
# 	max attention: 0.9998, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.9124, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 2, 0, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_HEAD)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.9625, min attention: 0.0000
# neighbourhood stats for node=106:
# 	max attention: 1.0000, min attention: 0.0000
# neighbourhood stats for node=30:
# 	max attention: 0.9998, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.9971, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 0, 0, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_NODE)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.2869, min attention: 0.1214
# neighbourhood stats for node=106:
# 	max attention: 0.7445, min attention: 0.0015
# neighbourhood stats for node=30:
# 	max attention: 0.6546, min attention: 0.0062
# neighbourhood stats for node=0:
# 	max attention: 0.6502, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 1, 0, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_NODE)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.4588, min attention: 0.0099
# neighbourhood stats for node=106:
# 	max attention: 0.9114, min attention: 0.0000
# neighbourhood stats for node=30:
# 	max attention: 0.9998, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.9124, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 2, 0, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_NODE)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.9625, min attention: 0.0000
# neighbourhood stats for node=106:
# 	max attention: 1.0000, min attention: 0.0000
# neighbourhood stats for node=30:
# 	max attention: 0.9998, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.9971, min attention: 0.0000

# %% [markdown]
# #### Neighbourhood attention learned by the classification layer heads

# %%
visualise_neighbourhoods_for(model, test_graph, 2, 0, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_HEAD)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.9625, min attention: 0.0000
# neighbourhood stats for node=106:
# 	max attention: 1.0000, min attention: 0.0000
# neighbourhood stats for node=30:
# 	max attention: 0.9998, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.9971, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 2, 1, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_HEAD)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.8087, min attention: 0.0001
# neighbourhood stats for node=106:
# 	max attention: 1.0000, min attention: 0.0000
# neighbourhood stats for node=30:
# 	max attention: 0.9388, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.7381, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 2, 2, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_HEAD)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 1.0000, min attention: 0.0000
# neighbourhood stats for node=106:
# 	max attention: 0.3755, min attention: 0.0000
# neighbourhood stats for node=30:
# 	max attention: 0.8283, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.8535, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 2, 3, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_HEAD)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.9860, min attention: 0.0000
# neighbourhood stats for node=106:
# 	max attention: 0.8895, min attention: 0.0000
# neighbourhood stats for node=30:
# 	max attention: 0.9913, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.6299, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 2, 4, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_HEAD)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.9996, min attention: 0.0000
# neighbourhood stats for node=106:
# 	max attention: 0.8831, min attention: 0.0001
# neighbourhood stats for node=30:
# 	max attention: 0.4761, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.9685, min attention: 0.0000

# %%
visualise_neighbourhoods_for(model, test_graph, 2, 5, nodes_to_visualise, NeighbourhoodVisualisationMode.PER_HEAD)
# Out:
# neighbourhood stats for node=29:
# 	max attention: 0.9415, min attention: 0.0004
# neighbourhood stats for node=106:
# 	max attention: 1.0000, min attention: 0.0000
# neighbourhood stats for node=30:
# 	max attention: 0.9999, min attention: 0.0000
# neighbourhood stats for node=0:
# 	max attention: 0.6043, min attention: 0.0000
